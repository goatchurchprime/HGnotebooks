# %%
fname = "/home/julian/Downloads/Example UV file.txt.txt"
import pandas
k = pandas.read_csv(fname, skiprows=4, sep="\t")
k.columns = ["t"]+["c%d"%i  for i in range(0, len(k.columns)-1)]
k.t = pandas.to_datetime(k.t)
k.set_index("t", inplace=True)
k.index.name = None
k.head()
# Out:
#                           c0       c1       c2       c3       c4       c5  \
# 2019-04-04 15:17:53  1639.99  1652.29  1670.67  1698.90  1750.17  1768.15
# 2019-04-04 15:17:54  1635.54  1648.45  1677.27  1704.60  1747.25  1769.63
# 2019-04-04 15:17:55  1630.26  1660.39  1673.47  1702.45  1745.90  1771.12
# 2019-04-04 15:17:56  1636.57  1649.46  1672.72  1709.50  1753.96  1768.57
# 2019-04-04 15:17:56  1635.42  1658.77  1671.09  1698.40  1745.43  1766.54
#
#                           c6       c7       c8       c9  ...    c2018  \
# 2019-04-04 15:17:53  1785.28  1798.87  1814.42  1831.08  ...  1974.16
# 2019-04-04 15:17:54  1782.24  1800.26  1820.74  1830.92  ...  1975.90
# 2019-04-04 15:17:55  1790.74  1798.31  1812.00  1824.41  ...  1970.57
# 2019-04-04 15:17:56  1778.21  1794.18  1812.02  1821.92  ...  1967.09
# 2019-04-04 15:17:56  1783.82  1804.29  1809.43  1826.94  ...  1971.26
#
#                        c2019    c2020    c2021    c2022    c2023    c2024  \
# ...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.figure(figsize=(15,11))
plt.subplot(2,1,1)
plt.plot(k.c550)
plt.plot(k.c1900)
plt.legend()
plt.subplot(2,1,2)

for i in range(0, len(k), 150):
    plt.plot(list(k.iloc[i]), label=str(k.index[i]))
plt.legend()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(15,9))
plt.subplot(2,1,1)
plt.imshow(k)
plt.subplot(2,1,2)
plt.imshow(k, vmin=2500, vmax=3500)
